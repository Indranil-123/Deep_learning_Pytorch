# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
#check for GPU
if torch.cuda.is_available():
    print("GPU availbale")
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(device)
# Out:
# cpu

# %%
#starting with Tensors
#empty Tensor
a = torch.empty(2,3)

# %%
#type of Tensor Object
type(a)
# Out:
# torch.Tensor

# %%
#Zero Tensor
zero_tensor = torch.zeros(2,3)
zero_tensor
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
#Ones Tensor
one_tensor = torch.ones(2,3)
one_tensor
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
#seeding
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %% [markdown]
# ## Tensor Shape

# %%
#sometimes we need to create a similar shape of tensor
x = torch.tensor([[1,2,3],[1,2,3]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
#now we want to create a similar kind of tensor
new_x = torch.empty_like(x)

# %%
new_x.shape
# Out:
# torch.Size([2, 3])
